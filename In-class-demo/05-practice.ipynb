# %%
import pandas as pd

# %%
FILE_PATH = 'datasets/01-attendantsheet-sample.xlsx'

df = pd.read_excel(FILE_PATH)

# %%
df
# Out:
#                                            Unnamed: 0            Unnamed: 1  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2                                                 NaN                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                       Date: (MM/DD)                   NaN
# 7                                                 No.                  Name
# 8                                                   1            Chan Panha
# 9                                                   2  Chum Ratanakchentria
# 10                                                  3           Eang Montra
# ...

# %%
cleaned_df = df.rename(columns=df.iloc[7]).drop(range(0,8), axis=0).iloc[:22]

# %%
cleaned_df
# Out:
#                                                   No.                  Name  \
# 8                                                   1            Chan Panha
# 9                                                   2  Chum Ratanakchentria
# 10                                                  3           Eang Montra
# 11                                                  4          Eung Laimeng
# 12                                                  5      Soeun Kongsovann
# 13                                                  6           Kril Darith
# 14                                                  7  Mao Kolbotr Pisssoth
# 15                                                  8            Ny Clinton
# 16                                                  9  Phok Keomonnyratanak
# 17                                                 10      Rith Sokha Neadh
# 18                                                 11              Sat Dona
# ...
